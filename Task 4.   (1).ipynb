# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = r'D:\Machine learning 2\Data 2.txt'
data = pd.read_csv(path, header=None, names=['col1' , 'col2' , 'col3' , 'col4' , 'col5' , 'col6' , 'col7' , 'col8' , 'col9' , 'col10' , 'col11' , 'col12' , 'col13 ', 'Target'])

print('data = ')
print(data.head(20) )
print()
print('data.describe = ')
print(data.describe())
# Out:
# data =
#     col1  col2  col3  col4  col5  col6  col7  col8  col9  col10  col11  col12  \
# 0     63     1     3   145   233     1     0   150     0    2.3      0      0
# 1     37     1     2   130   250     0     1   187     0    3.5      0      0
# 2     41     0     1   130   204     0     0   172     0    1.4      2      0
# 3     56     1     1   120   236     0     1   178     0    0.8      2      0
# 4     57     0     0   120   354     0     1   163     1    0.6      2      0
# 5     57     1     0   140   192     0     1   148     0    0.4      1      0
# 6     56     0     1   140   294     0     0   153     0    1.3      1      0
# 7     44     1     1   120   263     0     1   173     0    0.0      2      0
# 8     52     1     2   172   199     1     1   162     0    0.5      2      0
# 9     57     1     2   150   168     0     1   174     0    1.6      2      0
# 10    54     1     0   140   239     0     1   160     0    1.2      2      0
# ...

# %% [markdown]
# # Rearrange Data

# %%
positive = data[data['Target'].isin([1])]
negative = data[data['Target'].isin([0])]

print('................................................')
print('cancer')
print(positive)
print('................................................')
print('not cancer')
print(negative)
print('................................................')
# Out:
# ................................................
# cancer
#      col1  col2  col3  col4  col5  col6  col7  col8  col9  col10  col11  \
# 0      63     1     3   145   233     1     0   150     0    2.3      0
# 1      37     1     2   130   250     0     1   187     0    3.5      0
# 2      41     0     1   130   204     0     0   172     0    1.4      2
# 3      56     1     1   120   236     0     1   178     0    0.8      2
# 4      57     0     0   120   354     0     1   163     1    0.6      2
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...    ...    ...
# 160    56     1     1   120   240     0     1   169     0    0.0      0
# 161    55     0     1   132   342     0     1   166     0    1.2      2
# 162    41     1     1   120   157     0     1   182     0    0.0      2
# 163    38     1     2   138   175     0     1   173     0    0.0      2
# 164    38     1     2   138   175     0     1   173     0    0.0      2
#
#      col12  col13   Target
# ...
